# %% [markdown]
# <a href="https://colab.research.google.com/github/Canonik/Aluminum-Trump-assignments-/blob/main/trump_base_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q --upgrade transformers datasets peft accelerate

import torch, random, numpy as np
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)
import torch, time
from transformers import (
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    DataCollatorForSeq2Seq
)


MODEL_NAME = "google/flan-t5-large"


tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token


base_model = AutoModelForSeq2SeqLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,
    device_map="auto"
)
base_model.train()


sample_texts = [
    "What about COVID-19?",
    "Summarize Trump’s statements on the COVID-19 pandemic, focusing on his views on the government’s response, the role of China, and measures he promoted.",
    "How’s the economy?",
    "Summarize Trump’s position on the U.S. economy, including his claims about growth, unemployment, and stock market performance, with references to transcript passages.",
    "What about tariffs?",
    "Summarize Trump’s stance on tariffs, especially toward China, including his stated goals, justifications, and expected outcomes, citing transcript passages when possible.",
    "What about immigration?",
    "Summarize Trump’s position on immigration policy, highlighting his views on border security, the wall, and restrictions on entry, with supporting quotes.",
    "What about national security?",
    "Summarize Trump’s views on national security, focusing on military strength, terrorism, and foreign policy challenges, and reference transcript evidence when relevant."
]

for text in sample_texts:
    inputs = tokenizer(text, return_tensors="pt").to(base_model.device)
    with torch.no_grad():
        outputs = base_model.generate(
    **inputs,
    max_new_tokens=100,
    min_length=20,
    num_beams=4,
    do_sample=False
    )
    print("Query:", text)
    print("Response:", tokenizer.decode(outputs[0], skip_special_tokens=True))
    print("------")
# Out:
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Query: What about COVID-19?
# Response: What is COVID-19? COVID-19 is a genus of genus "Coviridae". It is a species of genus "Coviridae".
# ------
# Query: Summarize Trump’s statements on the COVID-19 pandemic, focusing on his views on the government’s response, the role of China, and measures he promoted.
# Response: Donald Trump’s statements on the COVID-19 pandemic, focusing on his views on the government’s response, the role of China, and measures he promoted.
# ------
# Query: How’s the economy?
# Response: it’s a good time to buy a home if you haven’t got one yet
# ------
# Query: Summarize Trump’s position on the U.S. economy, including his claims about growth, unemployment, and stock market performance, with references to transcript passages.
# Response: Trump’s comments on the U.S. economy, including his claims about growth, unemployment, and stock market performance, with references to transcript passages.
# ------
# Query: What about tariffs?
# Response: taxation on imports and tariffs on exports are two of the pillars of the economics of tariffs.
# ------
# Query: Summarize Trump’s stance on tariffs, especially toward China, including his stated goals, justifications, and expected outcomes, citing transcript passages when possible.
# Response: Read Trump’s stance on tariffs, especially toward China, including his stated goals, justifications, and expected outcomes.
# ------
# Query: What about immigration?
# Response: immigration to u s of america is a criminal offense , resulting in deportation , deportation, deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deportation , deport
# ------
# Query: Summarize Trump’s position on immigration policy, highlighting his views on border security, the wall, and restrictions on entry, with supporting quotes.
# Response: Trump’s position on immigration policy, highlighting his views on border security, the wall, and restrictions on entry, with supporting quotes.
# ------
# Query: What about national security?
# Response: is the responsibility of the federal government to ensure that all citizens have the right to privacy and security
# ------
# Query: Summarize Trump’s views on national security, focusing on military strength, terrorism, and foreign policy challenges, and reference transcript evidence when relevant.
# Response: The transcript of the President-elect’s address to the United States House of Representatives.
# ------
